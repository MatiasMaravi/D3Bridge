# %%
import vizpro.datasets as ds

iris = ds.get_dataset("iris")
iris
# Out:
# <Dataframe name='iris' rows=150 columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'target']>

# %%
from vizpro.graphs import Barplot

chart = Barplot(
    x="category",
    y="value", 
    hue="group",  # opcional
    direction="vertical",  # o "horizontal"
    palette=["#1f77b4", "#ff7f0e"],
    data=iris.data
)
chart
