# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
#%pip install -e .[dev]

# %%
from vizpro import CustomWidget, MatrixLayout, Datasets, MatrixCreator
import traitlets

# %%
affairs = Datasets.get_dataset("affairs")
affairs.head()
# Out:
# [{'rownames': 4,
#   'affairs': 0,
#   'gender': 'male',
#   'age': 37.0,
#   'yearsmarried': 10.0,
#   'children': 'no',
#   'religiousness': 3,
#   'education': 18,
#   'occupation': 7,
#   'rating': 4},
#  {'rownames': 5,
#   'affairs': 0,
#   'gender': 'female',
#   'age': 27.0,
#   'yearsmarried': 4.0,
#   'children': 'no',
#   'religiousness': 4,
#   'education': 14,
#   'occupation': 6,
#   'rating': 4},
#  {'rownames': 11,
#   'affairs': 0,
#   'gender': 'female',
#   'age': 32.0,
#   'yearsmarried': 15.0,
#   'children': 'yes',
#   'religiousness': 1,
#   'education': 12,
#   'occupation': 1,
#   'rating': 4},
#  {'rownames': 16,
#   'affairs': 0,
#   'gender': 'male',
#   'age': 57.0,
#   'yearsmarried': 15.0,
#   'children': 'yes',
#   'religiousness': 5,
#   'education': 18,
#   'occupation': 6,
#   'rating': 5},
#  {'rownames': 23,
#   'affairs': 0,
#   'gender': 'male',
#   'age': 22.0,
#   'yearsmarried': 0.75,
#   'children': 'no',
#   'religiousness': 2,
#   'education': 17,
#   'occupation': 6,
#   'rating': 3}]

# %%
import json
path_ = "../datasets/states-albers-10m.json"
mapa_data = json.load(open(path_))

# %%
path_map = r"..\samples\map.js"

class CustomMapa(CustomWidget):
    _esm = CustomWidget.createWidgetFromLocalFile(paramList=["data"], filePath=path_map,
                                                  extra_imports=['import * as topojson from "https://esm.sh/topojson-client@3";'])
    data = traitlets.Dict(mapa_data).tag(sync=True)
    selectedValues = traitlets.List([]).tag(sync=True)

    def on_select_values(self, callback):
        self.observe(callback, names=["selectedValues"])
    

map_widget = CustomMapa(data = mapa_data)

# %%
map_widget

# %%
df_sales = Datasets.get_dataset("sales")
df_sales.head()
# Out:
# [{'market': 'Auburn, AL', 'segment': 'Almond lovers', 'value': 3840},
#  {'market': 'Auburn, AL', 'segment': 'Berry buyers', 'value': 1920},
#  {'market': 'Auburn, AL', 'segment': 'Carrots-n-more', 'value': 960},
#  {'market': 'Auburn, AL', 'segment': 'Delicious-n-new', 'value': 400},
#  {'market': 'Birmingham, AL', 'segment': 'Almond lovers', 'value': 1600}]

# %%
class CustomMariko(CustomWidget):
    _esm = CustomWidget.createWidgetFromLocalFile(paramList=["data"], filePath=r"..\samples\mariko.js")
    data = traitlets.List([]).tag(sync=True)

mariko_widget = CustomMariko(data = df_sales.data)

# %%
mariko_widget

# %%
from vizpro import MatrixCreator

matrix = MatrixCreator(3,6)
matrix

# %%
matrix.data
# Out:
# [[1, 1, 1, 2, 2, 2], [1, 1, 1, 2, 2, 2], [1, 1, 1, 2, 2, 2]]

# %%
from vizpro import MatrixLayout

layout = MatrixLayout(matrix.data)

layout.add(map_widget,1)
layout.add(mariko_widget,2)

layout
