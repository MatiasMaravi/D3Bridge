# %% [markdown]
# load_ext autoreload: Evita que tengas que reiniciar el kernel
#
# autoreload 2: Coloca el modo de recarga en modo "Recargar todo"
#
# ANYWIDGET_HMR=1: Establece que Anywidget escuche los cambios que se produzcan en el backend

# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
from vizpro import Datasets

df_alphabet = Datasets().get_dataset("alphabet") #List

# %%
df_2 = Datasets().get_dataset("state-population-2010-2019")

# %%
from vizpro import CustomWidget, MatrixLayout, MatrixCreator
import traitlets

# %%
from vizpro import SwatchesInput
# Un selector de colores usando la paleta "Category10" de D3
color_picker1 = SwatchesInput()

# Visualizar
color_picker1

# %%
df_navegadores = Datasets.read_dataset(r"C:\Users\USUARIO\Desktop\vizpro-D3\navegadores.csv")
class CustomBarplot(CustomWidget):
    _esm = CustomWidget.createWidgetFromLocalFile(paramList=["data","x","y","pallete"], filePath=r"C:\Users\USUARIO\Desktop\vizpro-D3\vizpro\samples\d3_barchar.js")
    
    data = traitlets.List([]).tag(sync=True)
    x = traitlets.Unicode("").tag(sync=True)
    y = traitlets.Unicode("").tag(sync=True)
    pallete = traitlets.List(allow_none=True).tag(sync=True)

barplot = CustomBarplot(data=df_navegadores, x="navegador", y="frequency", pallete = color_picker1.value)

# %%
barplot

# %%
traitlets.link((color_picker1, 'value'), (barplot, 'pallete'))

# %%
from vizpro import RadioInput, RangeInput

# Radio buttons (equivalente a tu ejemplo)
metric = RadioInput(
    options=[("Absolute", "absolute"), ("Relative", "relative")],
    value="absolute",
    label="Change"
)

range_slider = RangeInput(
    min_val=2010,
    max_val=2019,
    step=1,
    value=[2010, 2019],
    label="Year Range"
)

# %%
range_slider

# %%
path = "samples/d3_barchar3.js"

class CustomBarplot3(CustomWidget):
    # Agregar 'metric' a la lista de parámetros
    _esm = CustomWidget.createWidgetFromLocalFile(paramList=["data", "metric"], filePath=path)

    data = traitlets.List([]).tag(sync=True)
    metric = traitlets.Unicode("absolute").tag(sync=True)  # Nuevo parámetro

barplot2 = CustomBarplot3(data=df_2.to_dict(orient="records"), metric="absolute")

# %%
# Vincular el RadioInput con el gráfico
traitlets.link((metric, "value"), (barplot2, "metric"))

# %%
metric

# %%
barplot2

# %%
m = MatrixCreator(3,3)
m

# %%
l = MatrixLayout(m.data)
l.add(metric,1)
l.add(barplot2,2)
l

# %%
ruta_3 = r"samples/sales.csv"

df_3 = pd.read_csv(ruta_3)
df_3.head()
# Out:
#            market          segment  value
# 0      Auburn, AL    Almond lovers   3840
# 1      Auburn, AL     Berry buyers   1920
# 2      Auburn, AL   Carrots-n-more    960
# 3      Auburn, AL  Delicious-n-new    400
# 4  Birmingham, AL    Almond lovers   1600

# %%
path = r'samples/mariko.js'
class CustomNuevo(CustomWidget):
    _esm = CustomWidget.createWidgetFromLocalFile(paramList=["data"], filePath=path)

    data = traitlets.List([]).tag(sync=True)


barplot3 = CustomNuevo(data=df_3.to_dict(orient="records"))

# %%
barplot3
